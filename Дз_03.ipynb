# %% [markdown]
# ### Домашнее задание <a class="anchor" id="hw"></a><center>

# %%
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# __Задача:__ подойдет ли репетитор для подготовки к экзамену по математике

# %%
X = np.array([ [   1,    1,  500,    1],
               [   1,    1,  700,    1],
               [   1,    2,  750,    2],
               [   1,    5,  600,    1],
               [   1,    3, 1450,    2],
               [   1,    0,  800,    1],
               [   1,    5, 1500,    3],
               [   1,   10, 2000,    3],
               [   1,    1,  450,    1],
               [   1,    2, 1000,    2]], dtype = np.float64)

y = np.array([0, 0, 1, 0, 1, 0, 1, 0, 1, 1])

# %%
def standard_scale(X):
    mean = X.mean(axis=0)
    std = X.std(axis=0)
    return (X - mean) / std

# %%
X_st = X.copy().astype(np.float64)
X_st[:, 1:4] = standard_scale(X_st[:, 1:4])
X_st
# Out:
# array([[ 1.        , -0.70710678, -0.97958969, -0.89625816],
#        [ 1.        , -0.70710678, -0.56713087, -0.89625816],
#        [ 1.        , -0.35355339, -0.46401617,  0.38411064],
#        [ 1.        ,  0.70710678, -0.77336028, -0.89625816],
#        [ 1.        ,  0.        ,  0.97958969,  0.38411064],
#        [ 1.        , -1.06066017, -0.36090146, -0.89625816],
#        [ 1.        ,  0.70710678,  1.08270439,  1.66447944],
#        [ 1.        ,  2.47487373,  2.11385144,  1.66447944],
#        [ 1.        , -0.70710678, -1.08270439, -0.89625816],
#        [ 1.        , -0.35355339,  0.05155735,  0.38411064]])

# %% [markdown]
# **1. *Измените функцию calc_logloss так, чтобы нули по возможности не попадали в np.log.**

# %% [markdown]
# 1 метод

# %%
def calc_logloss(y, y_pred):
    y_pred = np.where(y_pred == 1, 1 - 1e-8, y_pred)
    y_pred = np.where(y_pred == 0, 0 + 1e-8, y_pred)
    err = - np.mean(y * np.log(y_pred) + (1.0 - y) * np.log(1.0 - y_pred))
    return err

# %%
eps = 1e-8

np.clip([1, 0.5, 0], a_min=eps, a_max=1 - eps)
# Out:
# array([9.9999999e-01, 5.0000000e-01, 1.0000000e-08])

# %%
def calc_logloss(y, y_pred):
    eps = 1e-8
    y_pred = np.clip(y_pred, eps, 1 - eps)
    err = - np.mean(y * np.log(y_pred) + (1.0 - y) * np.log(1.0 - y_pred))
    return err

# %% [markdown]
# 2 метод

# %%
def calc_logloss(y, y_pred):
    err = 0
    for i in range(len(y)):
        if y_pred[i] == 0:
            err += (1.0 - y[i]) * np.log(1.0 - y_pred[i])
        elif y_pred[i] == 1:
            err += y[i] * np.log(y_pred[i])
        else:
            err += y[i] * np.log(y_pred[i]) + (1.0 - y[i]) * np.log(1.0 - y_pred[i])
    return - err / len(y)

# %%
y1 = np.array([1, 0])
y_pred1 = np.array([0.9, 0])
calc_logloss(y1, y_pred1)
# Out:
# 0.05268025782891314

# %%
y1 = np.array([1, 0])
y_pred1 = np.array([1, 0.1])
calc_logloss(y1, y_pred1)
# Out:
# 0.05268025782891314

# %%
y1 = np.array([1, 0])
y_pred1 = np.array([0.9, 0.1])
calc_logloss(y1, y_pred1)
# Out:
# 0.10536051565782628

# %% [markdown]
# **2. Подберите аргументы функции eval_model для логистической регрессии таким образом, чтобы log loss был минимальным.**

# %%
def sigmoid(z):
    res = 1 / (1 + np.exp(-z))
    return res

# %%
def eval_model(X, y, iterations, eta=1e-4):
    np.random.seed(42)
    W = np.random.randn(X.shape[1])
    n = X.shape[0]
    
    for i in range(iterations):
        z = np.dot(X, W)
        y_pred = sigmoid(z)
        err = calc_logloss(y, y_pred)
        
        dQ = 1/n * X.T @ (y_pred - y)
        W -= eta * dQ
        if i % (iterations / 10) == 0:
            print(i, W, err)
            
    final_error = calc_logloss(y, y_pred)
    return W, final_error

# %% [markdown]
# 1 метод
#
# аналог GridSearch

# %%
from tqdm import tqdm

# %%
np.logspace(2, 4, 4, dtype=np.int), np.linspace(1e-2, 5, 10)
# Out:
# (array([  100,   464,  2154, 10000]),
#  array([0.01      , 0.56444444, 1.11888889, 1.67333333, 2.22777778,
#         2.78222222, 3.33666667, 3.89111111, 4.44555556, 5.        ]))

# %%
iterations = np.logspace(2, 4, 4, dtype=np.int)
etas = np.linspace(1e-2, 5, 10)

best_error = np.inf
best_params = {}

for iteration in tqdm(iterations):
    for eta in etas:
        W, error = eval_model(X_st, y, iterations=iteration, eta=eta)
        if error < best_error:
            best_error = error
            best_params = {
                'iteration': iteration,
                'eta': eta
            }

print(f'Ошибка {best_error} при параметрах {best_params}')
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
# 0 [ 0.49635916 -0.1409725   0.64535427  1.52178506] 0.760958797591889
# 10 [ 0.49265881 -0.16787071  0.62221328  1.50954192] 0.7467006818024327
# 20 [ 0.48868992 -0.19442917  0.59944411  1.49767566] 0.7328651153682048
# 30 [ 0.48446029 -0.22063955  0.57705409  1.48619252] 0.7194524935754576
# 40 [ 0.47997869 -0.24649338  0.55505065  1.4750986 ] 0.7064630339679188
# 50 [ 0.47525478 -0.27198192  0.53344129  1.46439984] 0.6938967869573868
# 60 [ 0.47029912 -0.29709626  0.51223358  1.45410204] 0.6817536325961876
# 70 [ 0.46512312 -0.32182725  0.49143512  1.44421083] 0.6700332616838688
# 80 [ 0.45973898 -0.34616556  0.47105359  1.4347317 ] 0.658735139989009
# 90 [ 0.45415964 -0.37010173  0.4510966   1.42566993] 0.6478584551577353
# 0 [ 0.47667685 -0.29112687  0.51593213  1.45276794] 0.760958797591889
# 10 [ 0.15302827 -1.07349673 -0.05330995  1.447242  ] 0.458878668542744
# 20 [ 0.0338664  -1.33389885 -0.1641304   1.79467485] 0.41846490870843844
# 30 [-2.07371606e-03 -1.53135455e+00 -2.56777284e-01  2.10047940e+00] 0.3924986157098543
# 40 [-0.0121844  -1.69359169 -0.34448776  2.36758201] 0.37339237780194884
# 50 [-0.01242725 -1.8304667  -0.42806671  2.60495912] 0.35857692832071786
# 60 [-0.00785106 -1.94830994 -0.50787057  2.81896145] 0.34667943211441204
# 70 [-3.76878703e-04 -2.05145426e+00 -5.84193419e-01  3.01415763e+00] 0.3368637632041178
# 80 [ 0.00908442 -2.14297526 -0.6573095   3.19393641] 0.328587100896813
# 90 [ 0.02000313 -2.22512627 -0.72747734  3.36087607] 0.32148106741005017
# %%
def calc_pred_proba(W, X):
    y_pred_proba = sigmoid(np.dot(X, W))
    return y_pred_proba

# %%
calc_pred_proba(W, X_st)
# Out:
# array([8.93627716e-02, 6.82367011e-10, 1.00000000e+00, 2.08171530e-25,
#        9.93610002e-01, 4.50551813e-09, 1.00000000e+00, 1.63447642e-03,
#        9.14866911e-01, 1.00000000e+00])

# %% [markdown]
# **4. Создайте функцию calc_pred, возвращающую предсказанный класс (на вход подаются W, который уже посчитан функцией eval_model и X, на выходе - массив y_pred).**

# %%
def calc_pred(W, X):
    y_pred_proba = calc_pred_proba(W, X)
    y_pred = np.where(y_pred_proba > 0.5, 1, 0)
    return y_pred

# %%
pred = calc_pred(W, X_st)
pred
# Out:
# array([0, 0, 1, 0, 1, 0, 1, 0, 1, 1])

# %% [markdown]
# **5. *Реализуйте функции для подсчета Accuracy, матрицы ошибок, точности и полноты, а также F1 score.**

# %% [markdown]
# Accuracy

# %%
def accuracy(y, y_pred):
    accuracy = np.mean(y == y_pred)
    return accuracy

# %%
print(f'True \t  {y}')
print(f'Predicted {pred}')
# Out:
# True 	  [0 0 1 0 1 0 1 0 1 1]
# Predicted [0 0 1 0 1 0 1 0 1 1]

# %%
accuracy(y, pred)
# Out:
# 1.0

# %% [markdown]
# Confusion Matrix

# %%
# TP  FP
# FN  TN

# %%
def confusion_matrix(y, y_pred):
    cm = np.zeros((2, 2))
    for i in range(len(y)): 
        if y[i] == y_pred[i] == 1: # TP
            cm[0][0] += 1
        elif y[i] == y_pred[i] == 0: # TN
            cm[1][1] += 1
        elif y[i] != y_pred[i] and y[i] == 1: # FN
            cm[1][0] += 1
        elif y[i] != y_pred[i] and y[i] == 0: # FP
            cm[0][1] += 1
    return cm

# %%
cm = confusion_matrix(y, pred)
cm
# Out:
# array([[5., 0.],
#        [0., 5.]])

# %% [markdown]
# Precision

# %%
def precision(y, y_pred):
    cm = confusion_matrix(y, y_pred)
    TP = cm[0][0]
    TN = cm[1][1]
    FP = cm[0][1]
    FN = cm[1][0]
    precision = TP / (TP + FP)
    return precision

# %%
precision(y, pred)
# Out:
# 1.0

# %% [markdown]
# Recall

# %%
def recall(y, y_pred):
    cm = confusion_matrix(y, y_pred)
    TP = cm[0][0]
    TN = cm[1][1]
    FP = cm[0][1]
    FN = cm[1][0]
    recall = TP / (TP + FN)
    return recall

# %%
recall(y, pred)
# Out:
# 1.0

# %% [markdown]
# F-score

# %%
def f_score(y, y_pred):
    pr = precision(y, y_pred)
    rec = recall(y, y_pred)
    f_score = 2 * pr * rec / (pr + rec)
    return f_score

# %%
f_score(y, pred)
# Out:
# 1.0

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix


print(f'accuracy {accuracy_score(y, pred)}')
print(f'precision {precision_score(y, pred)}')
print(f'recall {recall_score(y, pred)}')
print(f'f-score {f1_score(y, pred)}')
print(f'\n {confusion_matrix(y, pred)}')
# Out:
# accuracy 1.0
# precision 1.0
# recall 1.0
# f-score 1.0
#
#  [[5 0]
#  [0 5]]

# %% [markdown]
# **6. Могла ли модель переобучиться? Почему?**
#
# Могла, если взять большое количество итераций, когда ошибка будет стремиться к нулю.
